# %% [markdown]
# <a href="https://colab.research.google.com/github/Rurieeeee/sistem-panen-terbaru-Nuri/blob/fitur-diskon/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# panen.py
def hitung_total_panen(jumlah_karung, berat_per_karung):
    return jumlah_karung * berat_per_karung

if __name__ == "__main__":
    karung = 10
    berat = 50
    total = hitung_total_panen(karung, berat)
    print(f"Total berat hasil panen: {total} kg")
# Out:
# Total berat hasil panen: 500 kg
